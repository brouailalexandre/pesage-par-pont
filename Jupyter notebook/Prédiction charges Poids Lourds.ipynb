# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
# %run "Fonctions.ipynb"

# %%
normandie = pd.read_csv('../Normandie/normandie.csv', low_memory=False)

# %%
millau = pd.read_csv('../Millau/Resultats/Fichiers Excel/new_millau.csv', low_memory=False)

# %% [markdown]
# ## Analyse succinte des données

# %%
normandie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 237584 entries, 0 to 237583
# Data columns (total 46 columns):
# timestamp        237584 non-null object
# warning flags    237584 non-null object
# lane             237584 non-null int64
# v                237584 non-null float64
# N                237584 non-null int64
# subclass id      237584 non-null int64
# axle groups      237584 non-null object
# gross weight     237584 non-null float64
# load_1           237584 non-null float64
# load_2           237584 non-null float64
# load_3           207372 non-null float64
# load_4           196550 non-null float64
# load_5           153292 non-null float64
# load_6           9265 non-null float64
# load_7           3636 non-null float64
# load_8           1651 non-null float64
# load_9           1201 non-null float64
# load_10          947 non-null float64
# load_11          720 non-null float64
# load_12          571 non-null float64
# load_13          421 non-null float64
# ...

# %%
normandie.describe()
# Out:
#                 lane              v              N   subclass id  \
# count  237584.000000  237584.000000  237584.000000  237584.00000
# mean        1.089190      19.277538       4.425370      88.06335
# std         0.285018       3.197534       1.227588      30.35567
# min         1.000000      10.014700       2.000000      10.00000
# 25%         1.000000      16.650400       4.000000      61.00000
# 50%         1.000000      19.051200       5.000000     103.00000
# 75%         1.000000      21.903700       5.000000     113.00000
# max         2.000000      44.521700      16.000000     140.00000
#
#         gross weight         load_1         load_2         load_3  \
# count  237584.000000  237584.000000  237584.000000  207372.000000
# mean      228.549278      55.460621      68.759756      43.858591
# std       111.396796      16.531074      34.321736      22.081528
# min         0.000000       0.000000       0.000000       0.000000
# ...

# %%
millau.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 165905 entries, 0 to 165904
# Data columns (total 46 columns):
# timestamp        165905 non-null object
# offset           165905 non-null float64
# site id          165905 non-null object
# stage trace      165905 non-null int64
# warning flags    165905 non-null object
# lane             165905 non-null int64
# v                165905 non-null float64
# N                165905 non-null int64
# subclass id      165905 non-null int64
# axle groups      165905 non-null object
# gross weight     165905 non-null float64
# load_1           165905 non-null float64
# load_2           165905 non-null float64
# load_3           107542 non-null float64
# load_4           100347 non-null float64
# load_5           82616 non-null float64
# load_6           2002 non-null float64
# load_7           1040 non-null float64
# load_8           714 non-null float64
# load_9           535 non-null float64
# load_10          399 non-null float64
# ...

# %%
millau.describe()
# Out:
#               offset  stage trace           lane              v  \
# count  165905.000000     165905.0  165905.000000  165905.000000
# mean        2.632730          0.0       1.073542      27.459491
# std         1.129112          0.0       0.261025       3.323031
# min         0.001000          0.0       1.000000      10.000000
# 25%         2.391000          0.0       1.000000      25.346500
# 50%         2.457000          0.0       1.000000      26.391800
# 75%         2.531000          0.0       1.000000      29.090900
# max        25.586000          0.0       2.000000      49.230800
#
#                    N    subclass id   gross weight         load_1  \
# count  165905.000000  165905.000000  165905.000000  165905.000000
# mean        3.784256      64.597697     197.773577      42.341967
# std         1.460598      30.253964     150.274962      24.226674
# min         2.000000      10.000000       0.000000       0.000000
# ...

# %%
pd.concat([count_null(millau), count_null(normandie)], keys=['Missing Normandie', 'Missing Millau'], axis=1)
# Out:
#               Missing Normandie Missing Millau
#                         Missing        Missing
# M                           NaN            0.0
# N                           0.0            0.0
# T                           0.0            0.0
# X2R                         0.0            0.0
# _long                       0.0            0.0
# axle groups                 0.0            0.0
# d_1                         0.0            0.0
# d_10                   165623.0       236864.0
# d_11                   165695.0       237013.0
# d_12                   165749.0       237152.0
# d_13                   165811.0       237239.0
# d_14                   165849.0       237337.0
# d_15                   165881.0       237414.0
# d_2                     58363.0        30212.0
# d_3                     65558.0        41034.0
# d_4                     83289.0        84292.0
# d_5                    163903.0       228319.0
# d_6                    164865.0       233948.0
# ...

# %% [markdown]
# ## Analyse graphiques

# %% [markdown]
# ### Normandie & Millau

# %% [markdown]
# #### Charge sur essieu

# %%
nbr_load = 8

load_list = list_multiple_var("load_", 1, nbr_load)
hist_load_list_norm = [kN_t(normandie[x]).fillna(50) for x in load_list]
hist_load_list_mil = [kN_t(millau[x]).fillna(50) for x in load_list]

# %%
for elt_mil, elt_norm in zip(hist_load_list_mil, hist_load_list_norm):
    plt.figure(figsize=(15, 6))

    plt.subplot(121)
    plt.hist([elt_norm, elt_mil], log=True)
    plt.title('Répartion des charges sur essieux \''+ str(elt_mil.name) +'\' - Fillna(50) - Log scale')
    plt.xlabel('Charge sur esieux (t)')
    plt.ylabel('Densité d\'apparition')
    plt.legend(["Normandie", "Millau"], loc='upper right', title="Légende :")
    
    plt.subplot(122)
    plt.hist([elt_norm, elt_mil])
    plt.title('Répartion des charges sur essieux \''+ str(elt_mil.name) +'\' - Fillna(50)')
    plt.xlabel('Charge sur esieux (t)')
    plt.ylabel('Densité d\'apparition')
    plt.legend(["Normandie", "Millau"], loc='upper right', title="Légende :")    
    
    plt.show()
# Out:
# C:\Users\brouail\AppData\Local\Continuum\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:52: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   return getattr(obj, method)(*args, **kwds)

# %% [markdown]
# #### Distance entre essieux

# %%
nbr_d = 7

d_list = list_multiple_var("d_", 1, nbr_d)
hist_d_list_norm = [normandie[x].fillna(20) for x in d_list]
hist_d_list_mil = [millau[x].fillna(20) for x in d_list]

# %%
for elt_mil, elt_norm in zip(hist_d_list_norm, hist_d_list_mil):
    plt.figure(figsize=(15, 6))

    plt.subplot(121)
    plt.hist([elt_norm, elt_mil], log=True)
    plt.title('Répartion des distances sur \''+ str(elt_mil.name) +'\' - Fillna(20) - Log scale')
    plt.xlabel('Distance entre esieux (m)')
    plt.ylabel('Densité d\'apparition')
    plt.legend(["Normandie", "Millau"], loc='upper right', title="Légende :")
    
    plt.subplot(122)
    plt.hist([elt_norm, elt_mil])
    plt.title('Répartion des distances sur \''+ str(elt_mil.name) +'\' - Fillna(20) - Log scale')
    plt.xlabel('Distance entre esieux (m)')
    plt.ylabel('Densité d\'apparition')
    plt.legend(["Normandie", "Millau"], loc='upper right', title="Légende :")    
    
    plt.show()
# Out:
# C:\Users\brouail\AppData\Local\Continuum\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:52: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   return getattr(obj, method)(*args, **kwds)

# %% [markdown]
# #### Longueur totale

# %%
plt.figure(figsize=(15, 6))

plt.subplot(121)
plt.hist([normandie['_long'], millau['_long']], log=True)
plt.title('Répartion de la longueur totale - Log scale')
plt.xlabel('Longueur totale (m)')
plt.ylabel('Densité d\'apparition')
plt.legend(["Normandie", "Millau"], loc='upper right', title="Légende :")

plt.subplot(122)
plt.hist([normandie['_long'], millau['_long']])
plt.title('Répartion de la longueur totale')
plt.xlabel('Longueur totale (m)')
plt.ylabel('Densité d\'apparition')
plt.legend(["Normandie", "Millau"], loc='upper right', title="Légende :")
plt.show()
# Out:
# C:\Users\brouail\AppData\Local\Continuum\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:52: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   return getattr(obj, method)(*args, **kwds)

# %% [markdown]
# #### Poids total

# %%
plt.figure(figsize=(15, 6))

plt.subplot(121)
plt.hist([kN_t(normandie['gross weight']), kN_t(millau['gross weight'])], log=True)
plt.title('Répartion du poids total - Log scale')
plt.xlabel('Poids total (t)')
plt.ylabel('Densité d\'apparition')
plt.legend(["Normandie", "Millau"], loc='upper right', title="Légende :")
          
plt.subplot(122)
plt.hist([kN_t(normandie['gross weight']), kN_t(millau['gross weight'])])
plt.title('Répartion du poids total')
plt.xlabel('Poids total (t)')
plt.ylabel('Densité d\'apparition')
plt.legend(["Normandie", "Millau"], loc='upper right', title="Légende :")

plt.show()
# Out:
# C:\Users\brouail\AppData\Local\Continuum\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:52: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   return getattr(obj, method)(*args, **kwds)

# %% [markdown]
# #### Nombre d'essieux

# %%
plt.figure(figsize=(15, 6))

plt.subplot(121)
plt.hist([normandie['N'], millau['N']], log=True)
plt.title('Répartion du nombre d\'essieux - Log scale')
plt.xlabel('Nombre d\'essieux')
plt.ylabel('Densité d\'apparition')
plt.legend(["Normandie", "Millau"], loc='upper right', title="Légende :")

plt.subplot(122)
plt.hist([normandie['N'], millau['N']])
plt.title('Répartion du nombre d\'essieux')
plt.xlabel('Nombre d\'essieux')
plt.ylabel('Densité d\'apparition')
plt.legend(["Normandie", "Millau"], loc='upper right', title="Légende :")

plt.show()
# Out:
# C:\Users\brouail\AppData\Local\Continuum\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:52: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   return getattr(obj, method)(*args, **kwds)

# %% [markdown]
# #### χ2

# %%
plt.figure(figsize=(15, 6))

plt.subplot(121)
plt.hist([normandie['X2R'], millau['X2R']], log=True)
plt.title('Répartion χ2 - Log scale')
plt.xlabel('χ2')
plt.ylabel('Densité d\'apparition')
plt.legend(["Normandie", "Millau"], loc='upper right', title="Légende :")

plt.subplot(122)
plt.hist([normandie['X2R'], millau['X2R']])
plt.title('Répartion χ2')
plt.xlabel('χ2')
plt.ylabel('Densité d\'apparition')
plt.legend(["Normandie", "Millau"], loc='upper right', title="Légende :")

plt.show()
# Out:
# C:\Users\brouail\AppData\Local\Continuum\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:52: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   return getattr(obj, method)(*args, **kwds)

# %% [markdown]
# #### Vitesse

# %%
plt.figure(figsize=(15, 6))

plt.subplot(121)
plt.hist([ms_kmh(normandie['v']), ms_kmh(millau['v'])], log=True)
plt.title('Répartion des vitesses - Log scale')
plt.xlabel('Vitesse (km/h)')
plt.ylabel('Densité d\'apparition')
plt.legend(["Normandie", "Millau"], loc='upper right', title="Légende :")

plt.subplot(122)
plt.hist([ms_kmh(normandie['v']), ms_kmh(millau['v'])])
plt.title('Répartion des vitesses')
plt.xlabel('Vitesse (km/h)')
plt.ylabel('Densité d\'apparition')
plt.legend(["Normandie", "Millau"], loc='upper right', title="Légende :")

plt.show()
# Out:
# C:\Users\brouail\AppData\Local\Continuum\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:52: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   return getattr(obj, method)(*args, **kwds)

# %% [markdown]
# ### Analyse des corrélations

# %% [markdown]
# #### Normandie

# %%
normandie.corr(method='pearson').style.format("{:.2}").background_gradient(cmap=plt.get_cmap('coolwarm'), axis=1)
# Out:
# C:\Users\brouail\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\colors.py:489: RuntimeWarning: invalid value encountered in less
#   np.copyto(xa, -1, where=xa < 0.0)
# <style  type="text/css" >
#     #T_ee3fcdfe_5a69_11e8_a131_b8ac6f8535cfrow0_col0 {
#             background-color:  #b40426;
#         }    #T_ee3fcdfe_5a69_11e8_a131_b8ac6f8535cfrow0_col1 {
#             background-color:  #b6cefa;
#         }    #T_ee3fcdfe_5a69_11e8_a131_b8ac6f8535cfrow0_col2 {
#             background-color:  #8db0fe;
#         }    #T_ee3fcdfe_5a69_11e8_a131_b8ac6f8535cfrow0_col3 {
#             background-color:  #8badfd;
#         }    #T_ee3fcdfe_5a69_11e8_a131_b8ac6f8535cfrow0_col4 {
#             background-color:  #7597f6;
#         }    #T_ee3fcdfe_5a69_11e8_a131_b8ac6f8535cfrow0_col5 {
#             background-color:  #5572df;
#         }    #T_ee3fcdfe_5a69_11e8_a131_b8ac6f8535cfrow0_col6 {
#             background-color:  #81a4fb;
# ...

# %% [markdown]
# #### Millau

# %%
millau.corr(method='pearson').style.format("{:.2}").background_gradient(cmap=plt.get_cmap('coolwarm'), axis=1)
# Out:
# C:\Users\brouail\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\colors.py:489: RuntimeWarning: invalid value encountered in less
#   np.copyto(xa, -1, where=xa < 0.0)
# <style  type="text/css" >
#     #T_ef2bd886_5a69_11e8_9f50_b8ac6f8535cfrow0_col0 {
#             background-color:  #b40426;
#         }    #T_ef2bd886_5a69_11e8_9f50_b8ac6f8535cfrow0_col1 {
#             background-color:  #3b4cc0;
#         }    #T_ef2bd886_5a69_11e8_9f50_b8ac6f8535cfrow0_col2 {
#             background-color:  #80a3fa;
#         }    #T_ef2bd886_5a69_11e8_9f50_b8ac6f8535cfrow0_col3 {
#             background-color:  #506bda;
#         }    #T_ef2bd886_5a69_11e8_9f50_b8ac6f8535cfrow0_col4 {
#             background-color:  #7699f6;
#         }    #T_ef2bd886_5a69_11e8_9f50_b8ac6f8535cfrow0_col5 {
#             background-color:  #7699f6;
#         }    #T_ef2bd886_5a69_11e8_9f50_b8ac6f8535cfrow0_col6 {
#             background-color:  #80a3fa;
# ...

# %% [markdown]
# ### DataFrame floatante

# %% [markdown]
# #### Cas particuliers

# %%
# Suppression des lignes 'axle groups' avec virgule
normandie = normandie[~normandie['axle groups'].apply(lambda x: '.' in x)]
millau = millau[~millau['axle groups'].apply(lambda x: '.' in x)]

# %% [markdown]
# #### Normandie

# %%
normandie_df = pd.DataFrame()
normandie_df = pd.concat([normandie_df, timestamp_dummies(normandie['timestamp'])], axis=1)
normandie_df = pd.concat([normandie_df, warningFlags_dummies(normandie['warning flags'])], axis=1)
normandie_df[['lane', 'N', 'subclass id']] = normandie[['lane', 'N', 'subclass id']]
normandie_df['v'] = ms_kmh(normandie['v'])
normandie_df = pd.concat([normandie_df, axleGroups_dummies(normandie['axle groups'])], axis=1)
normandie_df['gross weight'] = kN_t(normandie['gross weight'])
normandie_df[['_long', 'T', 'X2R', 'sum_strip_1', 'sum_strip_2']] = normandie[['_long', 'T', 'X2R', 'sum_strip_1', 'sum_strip_2']]
normandie_df[list_multiple_var('load_', 1, 16)] = kN_t(normandie[list_multiple_var('load_', 1, 16)])
normandie_df[list_multiple_var('d_', 1, 15)] = kN_t(normandie[list_multiple_var('d_', 1, 15)])

# %% [markdown]
# #### Millau

# %%
millau_df = pd.DataFrame()
millau_df = pd.concat([millau_df, timestamp_dummies(millau['timestamp'])], axis=1)
millau_df = pd.concat([millau_df, warningFlags_dummies(millau['warning flags'])], axis=1)
millau_df[['offset', 'lane', 'N', 'subclass id']] = millau[['offset', 'lane', 'N', 'subclass id']]
millau_df['v'] = ms_kmh(millau['v'])
millau_df = pd.concat([millau_df, axleGroups_dummies(millau['axle groups'])], axis=1)
millau_df['gross weight'] = kN_t(millau['gross weight'])
millau_df[['_long', 'T', 'X2R']] = millau[['_long', 'T', 'X2R']]
millau_df[list_multiple_var('load_', 1, 16)] = kN_t(millau[list_multiple_var('load_', 1, 16)])
millau_df[list_multiple_var('d_', 1, 15)] = kN_t(millau[list_multiple_var('d_', 1, 15)])

# %%
normandie_df.corr(method='pearson').style.format("{:.2}").background_gradient(cmap=plt.get_cmap('coolwarm'), axis=1)
# Out:
# C:\Users\brouail\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\colors.py:489: RuntimeWarning: invalid value encountered in less
#   np.copyto(xa, -1, where=xa < 0.0)
# <style  type="text/css" >
#     #T_c3967106_5a74_11e8_8043_b8ac6f8535cfrow0_col0 {
#             background-color:  #b40426;
#         }    #T_c3967106_5a74_11e8_8043_b8ac6f8535cfrow0_col1 {
#             background-color:  #3b4cc0;
#         }    #T_c3967106_5a74_11e8_8043_b8ac6f8535cfrow0_col2 {
#             background-color:  #d5dbe5;
#         }    #T_c3967106_5a74_11e8_8043_b8ac6f8535cfrow0_col3 {
#             background-color:  #d5dbe5;
#         }    #T_c3967106_5a74_11e8_8043_b8ac6f8535cfrow0_col4 {
#             background-color:  #d4dbe6;
#         }    #T_c3967106_5a74_11e8_8043_b8ac6f8535cfrow0_col5 {
#             background-color:  #d5dbe5;
#         }    #T_c3967106_5a74_11e8_8043_b8ac6f8535cfrow0_col6 {
#             background-color:  #d5dbe5;
# ...

# %%
millau_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 165905 entries, 0 to 165904
# Data columns (total 71 columns):
# Year             165905 non-null int64
# Month            165905 non-null int64
# Day              165905 non-null int64
# Hour             165905 non-null int64
# Minute           165905 non-null int64
# Seconde          165905 non-null int64
# Millisecondes    165905 non-null int64
# W7               165905 non-null int64
# W6               165905 non-null int64
# W5               165905 non-null int64
# W4               165905 non-null int64
# W3               165905 non-null int64
# W2               165905 non-null int64
# W1               165905 non-null int64
# W0               165905 non-null int64
# offset           165905 non-null float64
# lane             165905 non-null int64
# N                165905 non-null int64
# subclass id      165905 non-null int64
# v                165905 non-null float64
# AG_1             165905 non-null int64
# ...

# %%
df = pd.concat([normandie, warningFlags], axis=1)
df.drop(['warning flags', 'W7'], axis=1, inplace=True)

# %%
# Suppression WF 0x80 : Negative axle loads
df.drop(df[df['W2'] == 8].index, inplace=True)

# Suppression load_1 == 0 et load_2 <= 0
df.drop(df[df['load_1'] == 0].index, inplace=True)
df.drop(df[df['load_2'] <= 0].index, inplace=True)

# Suppression d <0
str_d = 'd_'
for i in range(1, 16):
    df.drop(df[df[str_d+str(i)] < 0].index, inplace=True)
    
# Suppression _long < 0
df.drop(df[df['_long'] < 0].index, inplace=True)

# %%
neg_w2 = len(df[df['W2'] == 8 ])
print("Negative axle loads : " + str(neg_w2))

mult_w0 = len(df[df['W0'] == 1 ])
print("Multiple truck presence : " + str(mult_w0))

icomp_w6 = len(df[df['W6'] == 1 ])
print("Incomplete MP signals : " + str(icomp_w6))

for j in range(2):
    for i in range(1,17):
        if j and i == 16:
            break
        str_d = 'd_' if j else 'load_'
        str_sen = 'Dist. essieux ' if j else 'Charge essieu '
        sup = 7 if j else (20/0.102)
        unit = 'm' if j else 'kN'
        str_d += str(i)
        print(str_sen + "\t" + str_d + "\t neg : " + str(len(df[df[str_d] < 0])) + " \tnull : " + str(len(df[df[str_d] == 0]))  + " \tsup(>"+str(sup)+ unit +") : " + str(len(df[df[str_d] > sup])))
    
print("Poids brut total neg : " + str(len(df[df['gross weight'] < 0])) + ", null : " + str(len(df[df['gross weight'] == 0])) + " et sup(>70t) : " + str(len(df[df['gross weight'] > (70/0.102)])))
print("Longueur neg : " + str(len(df[df['_long'] < 0])) + ", null : " + str(len(df[df['_long'] == 0])) + " et hors(2< x <25m) : " + str(len(df[df['_long'] > 25]) + len(df[df['_long'] < 2])))
print("Nbr essieux sup(>6) : " + str(len(df[df['N'] > 6])))
# Out:
# Negative axle loads : 0
# Multiple truck presence : 16781
# Incomplete MP signals : 5905
# Charge essieu 	load_1	 neg : 0 	null : 0 	sup(>196.07843137254903kN) : 0
# Charge essieu 	load_2	 neg : 0 	null : 0 	sup(>196.07843137254903kN) : 0
# Charge essieu 	load_3	 neg : 0 	null : 0 	sup(>196.07843137254903kN) : 0
# Charge essieu 	load_4	 neg : 0 	null : 0 	sup(>196.07843137254903kN) : 0
# Charge essieu 	load_5	 neg : 0 	null : 0 	sup(>196.07843137254903kN) : 0
# Charge essieu 	load_6	 neg : 0 	null : 0 	sup(>196.07843137254903kN) : 0
# Charge essieu 	load_7	 neg : 0 	null : 0 	sup(>196.07843137254903kN) : 0
# Charge essieu 	load_8	 neg : 0 	null : 0 	sup(>196.07843137254903kN) : 0
# Charge essieu 	load_9	 neg : 0 	null : 0 	sup(>196.07843137254903kN) : 0
# Charge essieu 	load_10	 neg : 0 	null : 0 	sup(>196.07843137254903kN) : 0
# Charge essieu 	load_11	 neg : 0 	null : 0 	sup(>196.07843137254903kN) : 0
# Charge essieu 	load_12	 neg : 0 	null : 0 	sup(>196.07843137254903kN) : 0
# ...

# %%
'''
Complétion des NaN
'''

df.fillna(-1, inplace=True)

# %%
normandie_df[normandie_df['W6'] == 1]
# Out:
#         Year  Month  Day  Hour  Minute  Seconde  Millisecondes  W7  W6  W5  \
# 31      2017      7    4    17      35       10            337   0   1   0
# 68      2017      7    4    17      56       20            767   0   1   0
# 71      2017      7    4    17      56       24            394   0   1   0
# 73      2017      7    4    17      56       27            232   0   1   0
# 127     2017      7    4    18      23       53            730   0   1   0
# 161     2017      7    4    18      50       24            544   0   1   0
# 190     2017      7    4    19      10       15            195   0   1   0
# 233     2017      7    4    19      45        5            966   0   1   0
# 273     2017      7    4    20      33       30            361   0   1   0
# 515     2017      7    5     6      28       58             87   0   1   0
# 555     2017      7    5     6      52        8            126   0   1   0
# ...
